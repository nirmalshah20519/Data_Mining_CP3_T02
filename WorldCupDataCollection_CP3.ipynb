# %% [markdown]
# # Scrapping/Collecting All Necessary Data

# %%
final_dataset_path = '/content/drive/MyDrive/DataMining/CP3_Datasets/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Kaggle/'

# %% [markdown]
# ##1. Kaggle Dataset 2023 ICC Men's Cricket World Cup
#
#
# The 2023 ICC Men's Cricket World Cup is the 13th edition of the Cricket World Cup, a quadrennial One Day International (ODI) cricket tournament contested by men's national teams and organized by the International Cricket Council (ICC). The tournament is currently being hosted by India, commencing on 5 October and scheduled to conclude on 19 November 2023.
#
# For more information, refer to the [Wikipedia page](https://en.wikipedia.org/wiki/2023_Cricket_World_Cup).
#
# ### Data Files
#
# - **deliveries.csv**: Contains ball-by-ball data for all matches.
# - **matches.csv**: Details for each match played.
# - **points_table.csv**: Current tournament standings.
#
# Feel free to explore the datasets to delve deeper into the exciting moments and statistics of the ongoing 2023 ICC Men's Cricket World Cup.

# %%
# !kaggle datasets download -d pardeep19singh/icc-mens-world-cup-2023 --force
# Out:
# Downloading icc-mens-world-cup-2023.zip to /content
#   0% 0.00/102k [00:00<?, ?B/s]
# 100% 102k/102k [00:00<00:00, 90.9MB/s]

# %%
import zipfile

zip_file_path = '/content/icc-mens-world-cup-2023.zip'
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(final_dataset_path)

# %% [markdown]
# ##2. ICC Men's Cricket Team Rankings
#
# The latest rankings of international cricket teams based on points, ratings, and positions. The data is scraped from [ICC Cricket Rankings](https://www.icc-cricket.com/rankings/mens/team-rankings/odi).
#
#
# ### Dataset Information
#
# The dataset, named **icc_rankings.csv**, includes the following key metrics for each team:
#
# - **Team**: The name of the cricket team.
# - **Points**: The total points earned by the team.
# - **Ratings**: The team's current rating.
# - **Position**: The team's position in the ICC rankings.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
data = []
table = soup.find('table', {'class': 'table'})
rows = table.find('tbody').find_all('tr')

for row in rows:
    cols = row.find_all(['td', 'th'])
    cols = [col.text.strip() for col in cols]
    data.append(cols)

icc_rankings = pd.DataFrame(data, columns=['Pos', 'Team', 'Matches', 'Points', 'Rating'])
icc_rankings['Team'] = icc_rankings['Team'].str.replace(r'\n.*', '', regex=True)

points_table = pd.read_csv(final_dataset_path+'points_table.csv')
Teams = list(points_table['Team'].unique())
icc_rankings =  icc_rankings[icc_rankings['Team'].isin(Teams)]

icc_rankings.to_csv(final_dataset_path+'icc_rankings.csv', index=False)

# %% [markdown]
# ##3. Historical ODI Matches Data
#
# The historical ODI matches dataset captures a range of information about cricket matches spanning from January 8, 2015, to May 14, 2023. The data includes key details for each match, offering insights into the dynamic world of One Day International cricket. Here's a brief overview of the data columns:
#
# - **Date:** The date when the match took place.
# - **Team_1 and Team_2:** The participating cricket teams in the match.
# - **Winner:** The team that emerged victorious in the match.
# - **Margin:** The margin of victory, providing details such as wickets taken, runs scored, or other relevant metrics.
# - **Ground:** The venue where the match was held.

# %%
import zipfile
import os

# Path to the ZIP file
zip_file_path = '/content/drive/MyDrive/DataMining/odis_json.zip'

# Directory to extract the contents to
extracted_dir = '/content/odis_json/'

# Create the target directory if it doesn't exist
os.makedirs(extracted_dir, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_dir)

# %%
import os
import json
import pandas as pd

# Path to the directory containing JSON files
json_dir = '/content/odis_json'

# Initialize lists to store extracted data
dates_list = []
team_1_list = []
team_2_list = []
winner_list = []
margin_list = []
ground_list = []
city_list = []

# Iterate through each JSON file in the directory
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        # Read the JSON file
        with open(os.path.join(json_dir, filename), 'r') as file:
            data = json.load(file)

        # Extract data from the JSON structure
        date = data['info']['dates'][0]
        teams = data['info']['teams']
        # Check if the 'outcome' key is present
        if 'outcome' in data['info']:
            outcome = data['info']['outcome']

            # Check if the 'winner' key is present in the 'outcome' dictionary
            if 'winner' in outcome:
                winner = outcome['winner']
                margin_info = outcome.get('by', {})

                # Convert margin information to a string
                if 'wickets' in margin_info:
                    margin = f"{margin_info['wickets']} wickets"
                elif 'runs' in margin_info:
                    margin = f"{margin_info['runs']} runs"
                else:
                    margin = "N/A"
            else:
                winner = "N/A"
                margin = "N/A"
        else:
            winner = "N/A"
            margin = "N/A"

        # Extract ground information
        ground = data['info']['venue']
        if 'city' in data['info']:
          city = data['info']['city']
        else:
          city = 'N/A'

        # Append data to the lists
        if data['info']['gender'] == 'male':
          dates_list.append(date)
          team_1_list.append(teams[0])
          team_2_list.append(teams[1])
          winner_list.append(winner)
          margin_list.append(margin)
          ground_list.append(ground)
          city_list.append(city)

# Create a DataFrame from the lists
historical_matches = pd.DataFrame({
    'Date': dates_list,
    'Team_1': team_1_list,
    'Team_2': team_2_list,
    'Winner': winner_list,
    'Margin': margin_list,
    'Ground': ground_list,
    'City': city_list
})

# %%
# Taking Matches between 1-Jan-2015 to 31-October-2023

historical_matches['Date'] = pd.to_datetime(historical_matches['Date'])

# Define the date range
start_date = '2015-01-01'
end_date = '2023-09-30'

mask = (historical_matches['Date'] >= start_date) & (historical_matches['Date'] <= end_date)

historical_matches = historical_matches[mask]
historical_matches = historical_matches.sort_values(by='Date')
historical_matches = historical_matches.reset_index(drop=True)
historical_matches.to_csv(final_dataset_path+'historical_matches.csv', index=False)

# %% [markdown]
# ##4. Cricket World Cup Fixtures Dataset
#
# The Scheduled ODI matches dataset captures a range of information about cricket matches scheduled For ICC Men's cricket Worldcup 2023. Here's a brief overview of the data columns:
#
# - **Date:** The date when the match took place.
# - **Team_1 and Team_2:** The participating cricket teams in the match.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get('https://www.cricketworldcup.com/fixtures')
soup = BeautifulSoup(response.text, 'html.parser')
all_matches = soup.find('div',class_='match-list__wrapper js-matchlist')
matches_list = all_matches.find_all('div', class_='match-block')
len(matches_list)
# Out:
# 48

# %%
Team_1s = []
Team_2s = []
Date = []
Ground = []
Venues = []
Cities = []

for m in matches_list:
  # Extracting information
  teams = m.select('.match-block__team-name')
  team_1 = teams[0].text.strip()
  team_2 = teams[1].text.strip()
  Team_1s.append(team_1)
  Team_2s.append(team_2)

  # Extracting date and ground with additional checks
  date_element = m.select_one('.match-block__date-user')
  date = date_element['data-startdate'] if date_element else None
  Date.append(date)

  venue = m.select('.match-block__venue-name')[0].text
  Venues.append(venue)
  city = venue.split(',')[-1].strip()
  Cities.append(city)

# Creating a DataFrame
data = {
    'Team_1': Team_1s,
    'Team_2': Team_2s,
    'Date': Date,
    'Venue':Venues,
    'City':Cities
}

fixtures = pd.DataFrame(data)
# for index, row in fixtures.iterrows():
#   if row['Team_2']=='Sri Lanka':
#     row['Team_1'], row['Team_2'] = row['Team_2'], row['Team_1']
#     break

# for index, row in fixtures.iterrows():
#   if row['Team_1']=='India':
#     row['Team_1'], row['Team_2'] = row['Team_2'], row['Team_1']
#     break
fixtures.to_csv(final_dataset_path+'fixtures.csv', index=False)
fixtures
# Out:
#                         Team_1                      Team_2  \
# 0                      England                 New Zealand
# 1                     Pakistan                 Netherlands
# 2                   Bangladesh                 Afghanistan
# 3                    Sri Lanka                South Africa
# 4                    Australia                       India
# 5                  New Zealand                 Netherlands
# 6                      England                  Bangladesh
# 7                     Pakistan                   Sri Lanka
# 8                        India                 Afghanistan
# 9                    Australia                South Africa
# 10                 New Zealand                  Bangladesh
# 11                       India                    Pakistan
# 12                     England                 Afghanistan
# 13                   Australia                   Sri Lanka
# 14                South Africa                 Netherlands
# 15                 New Zealand                 Afghanistan
# 16                       India                  Bangladesh
# 17                   Australia                    Pakistan
# 18                 Netherlands                   Sri Lanka
# 19                     England                South Africa
# 20                       India                 New Zealand
# 21                    Pakistan                 Afghanistan
# 22                South Africa                  Bangladesh
# 23                   Australia                 Netherlands
# 24                     England                   Sri Lanka
# 25                    Pakistan                South Africa
# 26                   Australia                 New Zealand
# 27                 Netherlands                  Bangladesh
# 28                       India                     England
# 29                 Afghanistan                   Sri Lanka
# 30                    Pakistan                  Bangladesh
# 31                 New Zealand                South Africa
# 32                       India                   Sri Lanka
# 33                 Netherlands                 Afghanistan
# 34                 New Zealand                    Pakistan
# 35                     England                   Australia
# 36                       India                South Africa
# 37                  Bangladesh                   Sri Lanka
# 38                   Australia                 Afghanistan
# 39                     England                 Netherlands
# 40                 New Zealand                   Sri Lanka
# 41                South Africa                 Afghanistan
# 42                   Australia                  Bangladesh
# 43                     England                    Pakistan
# 44                       India                 Netherlands
# 45                       India                 New Zealand
# 46                South Africa                   Australia
# 47  Winner of Semi-Final 1 Men  Winner of Semi-Final 2 Men
#
#                         Date                                          Venue  \
# 0   2023-10-05T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 1   2023-10-06T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 2   2023-10-07T10:30:00+0530                       HPCA Stadium, Dharamsala
# 3   2023-10-07T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 4   2023-10-08T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 5   2023-10-09T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 6   2023-10-10T10:30:00+0530                       HPCA Stadium, Dharamsala
# 7   2023-10-10T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 8   2023-10-11T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 9   2023-10-12T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 10  2023-10-13T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 11  2023-10-14T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 12  2023-10-15T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 13  2023-10-16T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 14  2023-10-17T14:00:00+0530                       HPCA Stadium, Dharamsala
# 15  2023-10-18T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 16  2023-10-19T14:00:00+0530                MCA International Stadium, Pune
# 17  2023-10-20T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 18  2023-10-21T10:30:00+0530               BRSABVE Cricket Stadium, Lucknow
# 19  2023-10-21T14:00:00+0530                       Wankhede Stadium, Mumbai
# 20  2023-10-22T14:00:00+0530                       HPCA Stadium, Dharamsala
# 21  2023-10-23T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 22  2023-10-24T14:00:00+0530                       Wankhede Stadium, Mumbai
# 23  2023-10-25T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 24  2023-10-26T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 25  2023-10-27T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 26  2023-10-28T10:30:00+0530                       HPCA Stadium, Dharamsala
# 27  2023-10-28T14:00:00+0530                          Eden Gardens, Kolkata
# 28  2023-10-29T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 29  2023-10-30T14:00:00+0530                MCA International Stadium, Pune
# 30  2023-10-31T14:00:00+0530                          Eden Gardens, Kolkata
# 31  2023-11-01T14:00:00+0530                MCA International Stadium, Pune
# 32  2023-11-02T14:00:00+0530                       Wankhede Stadium, Mumbai
# 33  2023-11-03T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 34  2023-11-04T10:30:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 35  2023-11-04T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 36  2023-11-05T14:00:00+0530                          Eden Gardens, Kolkata
# 37  2023-11-06T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 38  2023-11-07T14:00:00+0530                       Wankhede Stadium, Mumbai
# 39  2023-11-08T14:00:00+0530                MCA International Stadium, Pune
# 40  2023-11-09T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 41  2023-11-10T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 42  2023-11-11T10:30:00+0530                MCA International Stadium, Pune
# 43  2023-11-11T14:00:00+0530                          Eden Gardens, Kolkata
# 44  2023-11-12T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 45  2023-11-15T14:00:00+0530                       Wankhede Stadium, Mumbai
# 46  2023-11-16T14:00:00+0530                          Eden Gardens, Kolkata
# 47  2023-11-19T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
#
#           City
# 0    Ahmedabad
# 1    Hyderabad
# 2   Dharamsala
# 3        Delhi
# 4      Chennai
# 5    Hyderabad
# 6   Dharamsala
# 7    Hyderabad
# 8        Delhi
# 9      Lucknow
# 10     Chennai
# 11   Ahmedabad
# 12       Delhi
# 13     Lucknow
# 14  Dharamsala
# 15     Chennai
# 16        Pune
# 17   Bengaluru
# 18     Lucknow
# 19      Mumbai
# 20  Dharamsala
# 21     Chennai
# 22      Mumbai
# 23       Delhi
# 24   Bengaluru
# 25     Chennai
# 26  Dharamsala
# 27     Kolkata
# 28     Lucknow
# 29        Pune
# 30     Kolkata
# 31        Pune
# 32      Mumbai
# 33     Lucknow
# 34   Bengaluru
# 35   Ahmedabad
# 36     Kolkata
# 37       Delhi
# 38      Mumbai
# 39        Pune
# 40   Bengaluru
# 41   Ahmedabad
# 42        Pune
# 43     Kolkata
# 44   Bengaluru
# 45      Mumbai
# 46     Kolkata
# 47   Ahmedabad

# %% [markdown]
# ##5. Cricket World Cup 2023 Dataset
#
# The Scheduled ODI matches dataset captures a range of information about cricket matches scheduled For ICC Men's cricket Worldcup 2023 along with their result. Here's a brief overview of the data columns:
#
# - **Date:** The date when the match took place.
# - **Team_1 and Team_2:** The participating cricket teams in the match.
# - **Winner** Winner of the match.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get('https://www.cricketworldcup.com/fixtures')
soup = BeautifulSoup(response.text, 'html.parser')
all_matches = soup.find('div',class_='match-list__wrapper js-matchlist')
matches_list = all_matches.find_all('div', class_='match-block')
len(matches_list)
# Out:
# 48

# %%
Team_1s = []
Team_2s = []
Date = []
Ground = []
Venues = []
Cities = []
Winner = []

for m in matches_list:
  # Extracting information
  teams = m.select('.match-block__team-name')
  team_1 = teams[0].text.strip()
  team_2 = teams[1].text.strip()
  Team_1s.append(team_1)
  Team_2s.append(team_2)

  # Extracting date and ground with additional checks
  date_element = m.select_one('.match-block__date-user')
  date = date_element['data-startdate'] if date_element else None
  Date.append(date)

  venue = m.select('.match-block__venue-name')[0].text
  Venues.append(venue)
  city = venue.split(',')[-1].strip()
  Cities.append(city)

  WinnerBlk = m.select('.match-block__header')[0]
  WinnerSpan = WinnerBlk.select('.match-block__header-bold')
  if len(WinnerSpan)>0:
    Winner.append(WinnerSpan[0].text.strip())
  else:
    Winner.append('NaN')

  # print(WinnerSpan)

# Creating a DataFrame
data = {
    'Team_1': Team_1s,
    'Team_2': Team_2s,
    'Date': Date,
    'Venue':Venues,
    'City':Cities,
    'Winner':Winner
}

result23 = pd.DataFrame(data)
for index, row in fixtures.iterrows():
  if row['Team_2']=='Sri Lanka':
    row['Team_1'], row['Team_2'] = row['Team_2'], row['Team_1']
    break

for index, row in fixtures.iterrows():
  if row['Team_1']=='India':
    row['Team_1'], row['Team_2'] = row['Team_2'], row['Team_1']
    break
result23.to_csv(final_dataset_path+'result23.csv', index=False)
result23
# Out:
#                         Team_1                      Team_2  \
# 0                      England                 New Zealand
# 1                     Pakistan                 Netherlands
# 2                   Bangladesh                 Afghanistan
# 3                 South Africa                   Sri Lanka
# 4                        India                   Australia
# 5                  New Zealand                 Netherlands
# 6                      England                  Bangladesh
# 7                     Pakistan                   Sri Lanka
# 8                        India                 Afghanistan
# 9                    Australia                South Africa
# 10                 New Zealand                  Bangladesh
# 11                       India                    Pakistan
# 12                     England                 Afghanistan
# 13                   Australia                   Sri Lanka
# 14                South Africa                 Netherlands
# 15                 New Zealand                 Afghanistan
# 16                       India                  Bangladesh
# 17                   Australia                    Pakistan
# 18                 Netherlands                   Sri Lanka
# 19                     England                South Africa
# 20                       India                 New Zealand
# 21                    Pakistan                 Afghanistan
# 22                South Africa                  Bangladesh
# 23                   Australia                 Netherlands
# 24                     England                   Sri Lanka
# 25                    Pakistan                South Africa
# 26                   Australia                 New Zealand
# 27                 Netherlands                  Bangladesh
# 28                       India                     England
# 29                 Afghanistan                   Sri Lanka
# 30                    Pakistan                  Bangladesh
# 31                 New Zealand                South Africa
# 32                       India                   Sri Lanka
# 33                 Netherlands                 Afghanistan
# 34                 New Zealand                    Pakistan
# 35                     England                   Australia
# 36                       India                South Africa
# 37                  Bangladesh                   Sri Lanka
# 38                   Australia                 Afghanistan
# 39                     England                 Netherlands
# 40                 New Zealand                   Sri Lanka
# 41                South Africa                 Afghanistan
# 42                   Australia                  Bangladesh
# 43                     England                    Pakistan
# 44                       India                 Netherlands
# 45                       India                 New Zealand
# 46                South Africa                   Australia
# 47  Winner of Semi-Final 1 Men  Winner of Semi-Final 2 Men
#
#                         Date                                          Venue  \
# 0   2023-10-05T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 1   2023-10-06T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 2   2023-10-07T10:30:00+0530                       HPCA Stadium, Dharamsala
# 3   2023-10-07T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 4   2023-10-08T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 5   2023-10-09T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 6   2023-10-10T10:30:00+0530                       HPCA Stadium, Dharamsala
# 7   2023-10-10T14:00:00+0530  Rajiv Gandhi International Stadium, Hyderabad
# 8   2023-10-11T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 9   2023-10-12T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 10  2023-10-13T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 11  2023-10-14T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 12  2023-10-15T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 13  2023-10-16T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 14  2023-10-17T14:00:00+0530                       HPCA Stadium, Dharamsala
# 15  2023-10-18T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 16  2023-10-19T14:00:00+0530                MCA International Stadium, Pune
# 17  2023-10-20T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 18  2023-10-21T10:30:00+0530               BRSABVE Cricket Stadium, Lucknow
# 19  2023-10-21T14:00:00+0530                       Wankhede Stadium, Mumbai
# 20  2023-10-22T14:00:00+0530                       HPCA Stadium, Dharamsala
# 21  2023-10-23T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 22  2023-10-24T14:00:00+0530                       Wankhede Stadium, Mumbai
# 23  2023-10-25T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 24  2023-10-26T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 25  2023-10-27T14:00:00+0530                MA Chidambaram Stadium, Chennai
# 26  2023-10-28T10:30:00+0530                       HPCA Stadium, Dharamsala
# 27  2023-10-28T14:00:00+0530                          Eden Gardens, Kolkata
# 28  2023-10-29T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 29  2023-10-30T14:00:00+0530                MCA International Stadium, Pune
# 30  2023-10-31T14:00:00+0530                          Eden Gardens, Kolkata
# 31  2023-11-01T14:00:00+0530                MCA International Stadium, Pune
# 32  2023-11-02T14:00:00+0530                       Wankhede Stadium, Mumbai
# 33  2023-11-03T14:00:00+0530               BRSABVE Cricket Stadium, Lucknow
# 34  2023-11-04T10:30:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 35  2023-11-04T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 36  2023-11-05T14:00:00+0530                          Eden Gardens, Kolkata
# 37  2023-11-06T14:00:00+0530                    Arun Jaitley Stadium, Delhi
# 38  2023-11-07T14:00:00+0530                       Wankhede Stadium, Mumbai
# 39  2023-11-08T14:00:00+0530                MCA International Stadium, Pune
# 40  2023-11-09T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 41  2023-11-10T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
# 42  2023-11-11T10:30:00+0530                MCA International Stadium, Pune
# 43  2023-11-11T14:00:00+0530                          Eden Gardens, Kolkata
# 44  2023-11-12T14:00:00+0530              M. Chinnaswamy Stadium, Bengaluru
# 45  2023-11-15T14:00:00+0530                       Wankhede Stadium, Mumbai
# 46  2023-11-16T14:00:00+0530                          Eden Gardens, Kolkata
# 47  2023-11-19T14:00:00+0530               Narendra Modi Stadium, Ahmedabad
#
#           City        Winner
# 0    Ahmedabad   New Zealand
# 1    Hyderabad      Pakistan
# 2   Dharamsala    Bangladesh
# 3        Delhi  South Africa
# 4      Chennai         India
# 5    Hyderabad   New Zealand
# 6   Dharamsala       England
# 7    Hyderabad      Pakistan
# 8        Delhi         India
# 9      Lucknow  South Africa
# 10     Chennai   New Zealand
# 11   Ahmedabad         India
# 12       Delhi   Afghanistan
# 13     Lucknow     Australia
# 14  Dharamsala   Netherlands
# 15     Chennai   New Zealand
# 16        Pune         India
# 17   Bengaluru     Australia
# 18     Lucknow     Sri Lanka
# 19      Mumbai  South Africa
# 20  Dharamsala         India
# 21     Chennai   Afghanistan
# 22      Mumbai  South Africa
# 23       Delhi     Australia
# 24   Bengaluru     Sri Lanka
# 25     Chennai  South Africa
# 26  Dharamsala     Australia
# 27     Kolkata   Netherlands
# 28     Lucknow         India
# 29        Pune   Afghanistan
# 30     Kolkata      Pakistan
# 31        Pune  South Africa
# 32      Mumbai         India
# 33     Lucknow   Afghanistan
# 34   Bengaluru      Pakistan
# 35   Ahmedabad     Australia
# 36     Kolkata         India
# 37       Delhi    Bangladesh
# 38      Mumbai     Australia
# 39        Pune       England
# 40   Bengaluru   New Zealand
# 41   Ahmedabad  South Africa
# 42        Pune     Australia
# 43     Kolkata       England
# 44   Bengaluru         India
# 45      Mumbai           NaN
# 46     Kolkata           NaN
# 47   Ahmedabad           NaN

# %%
result23[['Team_1', 'Team_2', 'City', 'Winner']][:44].head(3)
# Out:
#        Team_1       Team_2        City       Winner
# 0     England  New Zealand   Ahmedabad  New Zealand
# 1    Pakistan  Netherlands   Hyderabad     Pakistan
# 2  Bangladesh  Afghanistan  Dharamsala   Bangladesh

# %% [markdown]
# ##6. Cricket World Cup 2023 Squad Collection
#
# Gathering team-specific squads to formulate an 11-player forecast for the Cricket World Cup 2023 finalists. This involves a comprehensive analysis of each team's selected players, considering their individual strengths, playing styles, and recent performances, to predict the optimal lineup for the potential finalists in the upcoming tournament.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/2023_Cricket_World_Cup_squads'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
all_teams = soup.find_all('table',class_='sortable')
all_teams_names = soup.find_all('span',class_='mw-headline')[1:11]
all_teams_names = [i.text for i in all_teams_names]
# teams_list = all_teams.find_all('a', class_='team-index__link')
print(all_teams_names)
print(len(all_teams))
# all_teams[0]
# Out:
# ['Afghanistan', 'Australia', 'Bangladesh', 'England', 'India', 'Netherlands', 'New Zealand', 'Pakistan', 'South Africa', 'Sri Lanka']
# 10

# %%
# from io import StringIO

# for span in all_teams[0].find_all('span'):
#   span.unwrap()

# html_io = StringIO(str(all_teams[0]))

# df_list = pd.read_html(html_io)

# # Assume that the table of interest is the first one in the list
# df = df_list[0]

# df['Team'] = all_teams_names[0]
# # Display the DataFrame
# df.head()
# Out:
#     S/N                    Player                      Date of birth (age)  \
# 0    50  Hashmatullah Shahidi (c)    (1994-11-04)4 November 1994 (aged 28)
# 1    15                Noor Ahmad     (2005-01-03)3 January 2005 (aged 18)
# 2    46             Ikram Alikhil   (2000-11-28)28 November 2000 (aged 22)
# 3     5          Fazalhaq Farooqi  (2000-09-22)22 September 2000 (aged 23)
# 4    21   Rahmanullah Gurbaz (wk)   (2001-11-28)28 November 2001 (aged 21)
# 5    76               Riaz Hassan    (2002-11-07)7 November 2002 (aged 20)
# 6    19               Rashid Khan  (1998-09-20)20 September 1998 (aged 25)
# 7     7             Mohammad Nabi     (1985-01-01)1 January 1985 (aged 38)
# 8     9        Azmatullah Omarzai      (2000-03-24)24 March 2000 (aged 23)
# 9    27              Abdul Rahman   (2001-11-22)22 November 2001 (aged 21)
# 10    8               Rahmat Shah        (1993-07-06)6 July 1993 (aged 30)
# 11   78             Naveen-ul-Haq  (1999-09-23)23 September 1999 (aged 24)
# 12   88          Mujeeb Ur Rahman      (2001-03-28)28 March 2001 (aged 22)
# 13   18            Ibrahim Zadran   (2001-12-12)12 December 2001 (aged 21)
# 14    1         Najibullah Zadran   (1993-02-18)18 February 1993 (aged 30)
#
#     ODIs           Role Batting             Bowling style  \
# 0     64        Batsman    Left       Right-arm off break
# 1      3         Bowler   Right  Left-arm unorthodox spin
# 2     14  Wicket-keeper   Right                         –
# 3     21         Bowler   Right      Left-arm fast-medium
# 4     26  Wicket-keeper    Left                         –
# 5      5        Batsman   Right                         –
# 6     94    All-rounder   Right        Right-arm leg spin
# 7    147    All-rounder   Right        Right-arm off spin
# 8     13    All-rounder   Right     Right-arm medium-fast
# 9      3         Bowler   Right     Right-arm medium-fast
# 10    97        Batsman   Right       Right-arm leg break
# 11     7         Bowler   Right     Right-arm medium-fast
# 12    66         Bowler   Right       Right-arm off break
# 13    17        Batsman   Right     Right-arm medium-fast
# 14    90        Batsman    Left       Right-arm off break
#
#    List A or domestic team         Team
# 0       Band-e-Amir Region  Afghanistan
# 1        Mis Ainak Knights  Afghanistan
# 2         Speenghar Tigers  Afghanistan
# 3             Kabul Eagles  Afghanistan
# 4             Kabul Eagles  Afghanistan
# 5         Speenghar Tigers  Afghanistan
# 6         Speenghar Tigers  Afghanistan
# 7      Band-e-Amir Dragons  Afghanistan
# 8        Mis Ainak Knights  Afghanistan
# 9      Band-e-Amir Dragons  Afghanistan
# 10       Mis Ainak Knights  Afghanistan
# 11            Kabul Eagles  Afghanistan
# 12        Speenghar Tigers  Afghanistan
# 13         Boost Defenders  Afghanistan
# 14         Boost Defenders  Afghanistan

# %%
from io import StringIO

Squads = pd.DataFrame()

for index in range(len(all_teams)):

  for span in all_teams[index].find_all('span'):
    span.unwrap()

  html_io = StringIO(str(all_teams[index]))
  df_list = pd.read_html(html_io)

  curr_df = df_list[0]

  curr_df['Team'] = all_teams_names[index]

  Squads = pd.concat([Squads, curr_df], ignore_index=True)

# %%
print(Squads.shape)
Squads
# Out:
# (162, 9)
#       S/N                    Player                      Date of birth (age)  \
# 0    50.0  Hashmatullah Shahidi (c)    (1994-11-04)4 November 1994 (aged 28)
# 1    15.0                Noor Ahmad     (2005-01-03)3 January 2005 (aged 18)
# 2    46.0             Ikram Alikhil   (2000-11-28)28 November 2000 (aged 22)
# 3     5.0          Fazalhaq Farooqi  (2000-09-22)22 September 2000 (aged 23)
# 4    21.0   Rahmanullah Gurbaz (wk)   (2001-11-28)28 November 2001 (aged 21)
# ..    ...                       ...                                      ...
# 157  61.0        Maheesh Theekshana      (2000-08-01)1 August 2000 (aged 23)
# 158   1.0          Dunith Wellalage     (2003-01-09)9 January 2003 (aged 20)
# 159   7.0         Dasun Shanaka (c)   (1991-09-09)9 September 1991 (aged 32)
# 160  81.0       Matheesha Pathirana   (2002-12-18)18 December 2002 (aged 20)
# 161   8.0             Lahiru Kumara   (1997-02-13)13 February 1997 (aged 26)
#
#      ODIs           Role Batting             Bowling style  \
# 0      64        Batsman    Left       Right-arm off break
# 1       3         Bowler   Right  Left-arm unorthodox spin
# 2      14  Wicket-keeper   Right                         –
# 3      21         Bowler   Right      Left-arm fast-medium
# 4      26  Wicket-keeper    Left                         –
# ..    ...            ...     ...                       ...
# 157    27         Bowler   Right        Right-arm off spin
# 158    15    All-rounder    Left    Slow left-arm orthodox
# 159    67    All-rounder   Right          Right-arm medium
# 160    10         Bowler   Right            Right-arm fast
# 161    26         Bowler    Left            Right-arm fast
#
#     List A or domestic team         Team
# 0        Band-e-Amir Region  Afghanistan
# 1         Mis Ainak Knights  Afghanistan
# 2          Speenghar Tigers  Afghanistan
# 3              Kabul Eagles  Afghanistan
# 4              Kabul Eagles  Afghanistan
# ..                      ...          ...
# 157                   Colts    Sri Lanka
# 158                   Colts    Sri Lanka
# 159               Sinhalese    Sri Lanka
# 160            Nondescripts    Sri Lanka
# 161            Nondescripts    Sri Lanka
#
# [162 rows x 9 columns]

# %%
Squads.to_csv(final_dataset_path+'Squads.csv', index=False)

# %%
team_counts = Squads.groupby('Team').size().reset_index(name='Count')

team_counts
# Out:
#            Team  Count
# 0   Afghanistan     15
# 1     Australia     16
# 2    Bangladesh     16
# 3       England     16
# 4         India     17
# 5   Netherlands     16
# 6   New Zealand     16
# 7      Pakistan     15
# 8  South Africa     17
# 9     Sri Lanka     18

# %%
Squads[Squads['Team']=='South Africa']
# Out:
#       S/N                 Player                     Date of birth (age)  \
# 127  11.0       Temba Bavuma (c)       (1990-05-17)17 May 1990 (aged 33)
# 128  62.0         Gerald Coetzee    (2000-10-02)2 October 2000 (aged 23)
# 129  12.0   Quinton de Kock (wk)  (1992-12-17)17 December 1992 (aged 30)
# 130  17.0        Reeza Hendricks    (1989-08-14)14 August 1989 (aged 34)
# 131  70.0           Marco Jansen        (2000-05-01)1 May 2000 (aged 23)
# 132  45.0  Heinrich Klaasen (wk)      (1991-07-30)30 July 1991 (aged 32)
# 133  16.0         Keshav Maharaj   (1990-02-07)7 February 1990 (aged 33)
# 134   4.0          Aiden Markram    (1994-10-04)4 October 1994 (aged 29)
# 135  10.0           David Miller      (1989-06-10)10 June 1989 (aged 34)
# 136  22.0            Lungi Ngidi     (1996-03-29)29 March 1996 (aged 27)
# 137  23.0     Andile Phehlukwayo      (1996-03-03)3 March 1996 (aged 27)
# 138  25.0          Kagiso Rabada       (1995-05-25)25 May 1995 (aged 28)
# 139  26.0         Tabraiz Shamsi  (1990-02-18)18 February 1990 (aged 33)
# 140   6.0        Lizaad Williams    (1993-10-01)1 October 1993 (aged 30)
# 141  72.0  Rassie van der Dussen   (1989-02-07)7 February 1989 (aged 34)
# 142  58.0         Sisanda Magala    (1991-01-07)7 January 1991 (aged 32)
# 143  20.0          Anrich Nortje  (1993-11-16)16 November 1993 (aged 29)
#
#      ODIs           Role Batting           Bowling style  \
# 127    28        Batsman   Right        Right-arm medium
# 128     6         Bowler   Right          Right-arm fast
# 129   145  Wicket-keeper    Left                       –
# 130    29        Batsman   Right     Right-arm off break
# 131    14    All-rounder   Right    Left-arm fast-medium
# 132    41  Wicket-keeper   Right      Right-arm off spin
# 133    31         Bowler   Right  Slow left-arm orthodox
# 134    55        Batsman   Right      Right-arm off spin
# 135   160        Batsman    Left      Right-arm off spin
# 136    48         Bowler   Right   Right-arm fast-medium
# 137    76    All-rounder    Left   Right-arm medium-fast
# 138    91         Bowler    Left          Right-arm fast
# 139    46         Bowler   Right     Left-arm wrist spin
# 140     1         Bowler    Left   Right-arm medium-fast
# 141    49        Batsman   Right      Right-arm leg spin
# 142     8         Bowler   Right   Right-arm fast-medium
# 143    22         Bowler   Right          Right-arm fast
#
#     List A or domestic team          Team
# 127                   Lions  South Africa
# 128                 Knights  South Africa
# 129                  Titans  South Africa
# 130                   Lions  South Africa
# 131                Warriors  South Africa
# 132                  Titans  South Africa
# 133                Dolphins  South Africa
# 134                  Titans  South Africa
# 135                Dolphins  South Africa
# 136                  Titans  South Africa
# 137                Dolphins  South Africa
# 138                   Lions  South Africa
# 139                  Titans  South Africa
# 140                  Titans  South Africa
# 141                   Lions  South Africa
# 142                   Lions  South Africa
# 143                Warriors  South Africa

# %% [markdown]
# # Points Table

# %% [markdown]
# The point table typically consists of columns displaying:
#
# 1.   Team Names
# 1.   Matches Played
# 1.   Matches Won
# 1.   Matches Lost
# 1.   Matches Tied or No Result (if applicable)
# 2.   Points Earned
# 7.   Net Run Rate (NRR)
#
# ## Points System:
#
# *   **Win**: Teams receive 2 points for a win.
# *   **Tie/No Result**: In case of a tie or a match abandoned due to weather, teams might share points or get one point each.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO

# %%
response = requests.get('https://www.cricbuzz.com/cricket-series/6732/icc-cricket-world-cup-2023/points-table')
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', class_='table cb-srs-pnts')

# %%
head = table.find('thead').find('tr')
cols = head.find_all('td')
cols = [tag.text for tag in cols]
cols
pts = head.find_all('th')
pts
# Out:
# [<th class="cb-srs-pnts-th text-left" style="padding-left: 6px;width:200px;">Teams</th>,
#  <th class="cb-srs-pnts-th" title="Match Points">Pts</th>,
#  <th></th>]

# %%
body = table.find('tbody')
rows = body.find_all('tr', class_="")
rows = rows[::13]
len(rows)
# Out:
# 10

# %%
rows[6]
# Out:
# <tr><th class="text-left">Opponent</th><th class="text-left">Description</th><th class="text-left">Date</th><th class="text-left">Result</th></tr>

# %%
point_tble = []

for inst in range(len(rows)):
  instance = {}
  features = rows[inst].find_all('td')
  print(features)

# features =
# instance['Team'] = 'India'
# for f in range(len(cols)):
#   row[0].find_all
# Out:
# [<td class="cb-srs-pnts-name" style="width:200px;"><a class="cb-text-link" href="/cricket-team/india/2"><div class="cb-col cb-col-100"><div class="cb-col cb-col-16"><img height="18" src="/a/img/v1/24x18/i1/c172115/india.jpg" style="padding:0px;" title="India" width="24"/></div><div class="cb-col cb-col-84">India<span class="cb-text-gray cb-font-10">  (Q)</span></div></div></a></td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td text-bold">18</td>, <td class="cb-srs-pnts-td">+2.570</td>, <td ng-init="direction_2_teams='up'"><a class="cb-srs-pnts-a cb-cursor" ng-click="(direction_2_teams=='up')?direction_2_teams = 'down' : direction_2_teams = 'up'" ng-cloak=""><span ng-class="(direction_2_teams=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></td>]
# []
# [<td class="cb-srs-pnts-name" style="width:200px;"><a class="cb-text-link" href="/cricket-team/south-africa/11"><div class="cb-col cb-col-100"><div class="cb-col cb-col-16"><img height="18" src="/a/img/v1/24x18/i1/c172126/south-africa.jpg" style="padding:0px;" title="South Africa" width="24"/></div><div class="cb-col cb-col-84">South Africa<span class="cb-text-gray cb-font-10">  (Q)</span></div></div></a></td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">7</td>, <td class="cb-srs-pnts-td">2</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td text-bold">14</td>, <td class="cb-srs-pnts-td">+1.261</td>, <td ng-init="direction_11_teams='up'"><a class="cb-srs-pnts-a cb-cursor" ng-click="(direction_11_teams=='up')?direction_11_teams = 'down' : direction_11_teams = 'up'" ng-cloak=""><span ng-class="(direction_11_teams=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></td>]
# []
# [<td class="cb-srs-pnts-name" style="width:200px;"><a class="cb-text-link" href="/cricket-team/australia/4"><div class="cb-col cb-col-100"><div class="cb-col cb-col-16"><img height="18" src="/a/img/v1/24x18/i1/c172117/australia.jpg" style="padding:0px;" title="Australia" width="24"/></div><div class="cb-col cb-col-84">Australia<span class="cb-text-gray cb-font-10">  (Q)</span></div></div></a></td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">7</td>, <td class="cb-srs-pnts-td">2</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td text-bold">14</td>, <td class="cb-srs-pnts-td">+0.841</td>, <td ng-init="direction_4_teams='up'"><a class="cb-srs-pnts-a cb-cursor" ng-click="(direction_4_teams=='up')?direction_4_teams = 'down' : direction_4_teams = 'up'" ng-cloak=""><span ng-class="(direction_4_teams=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></td>]
# []
# [<td class="cb-srs-pnts-name" style="width:200px;"><a class="cb-text-link" href="/cricket-team/new-zealand/13"><div class="cb-col cb-col-100"><div class="cb-col cb-col-16"><img height="18" src="/a/img/v1/24x18/i1/c172128/new-zealand.jpg" style="padding:0px;" title="New Zealand" width="24"/></div><div class="cb-col cb-col-84">New Zealand<span class="cb-text-gray cb-font-10">  (Q)</span></div></div></a></td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">5</td>, <td class="cb-srs-pnts-td">4</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td text-bold">10</td>, <td class="cb-srs-pnts-td">+0.743</td>, <td ng-init="direction_13_teams='up'"><a class="cb-srs-pnts-a cb-cursor" ng-click="(direction_13_teams=='up')?direction_13_teams = 'down' : direction_13_teams = 'up'" ng-cloak=""><span ng-class="(direction_13_teams=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></td>]
# []
# [<td class="cb-srs-pnts-name" style="width:200px;"><a class="cb-text-link" href="/cricket-team/pakistan/3"><div class="cb-col cb-col-100"><div class="cb-col cb-col-16"><img height="18" src="/a/img/v1/24x18/i1/c172116/pakistan.jpg" style="padding:0px;" title="Pakistan" width="24"/></div><div class="cb-col cb-col-84">Pakistan<span class="cb-text-gray cb-font-10">  (E)</span></div></div></a></td>, <td class="cb-srs-pnts-td">9</td>, <td class="cb-srs-pnts-td">4</td>, <td class="cb-srs-pnts-td">5</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td">0</td>, <td class="cb-srs-pnts-td text-bold">8</td>, <td class="cb-srs-pnts-td">-0.199</td>, <td ng-init="direction_3_teams='up'"><a class="cb-srs-pnts-a cb-cursor" ng-click="(direction_3_teams=='up')?direction_3_teams = 'down' : direction_3_teams = 'up'" ng-cloak=""><span ng-class="(direction_3_teams=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></td>]
# []
# [<td class="cb-srs-pnts-dwn" colspan="10"><div class="{{direction_96_teams}}" id="team_96" ng-cloak=""><table class="table cb-srs-pnts-dwn-tbl"><tr><th class="text-left">Opponent</th><th class="text-left">Description</th><th class="text-left">Date</th><th class="text-left">Result</th></tr><tr><td class="text-left">Bangladesh</td><td class="text-left">3rd Match</td><td class="text-left">07 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75427/ban-vs-afg-3rd-match-icc-cricket-world-cup-2023" title="Get live scores of Bangladesh vs Afghanistan, 3rd Match">Loss by 6 wkts</a></td></tr><tr><td class="text-left">India</td><td class="text-left">9th Match</td><td class="text-left">11 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75458/ind-vs-afg-9th-match-icc-cricket-world-cup-2023" title="Get live scores of India vs Afghanistan, 9th Match">Loss by 8 wkts</a></td></tr><tr><td class="text-left">England</td><td class="text-left">13th Match</td><td class="text-left">15 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75472/eng-vs-afg-13th-match-icc-cricket-world-cup-2023" title="Get live scores of England vs Afghanistan, 13th Match">Won by 69 runs</a></td></tr><tr><td class="text-left">New Zealand</td><td class="text-left">16th Match</td><td class="text-left">18 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75490/nz-vs-afg-16th-match-icc-cricket-world-cup-2023" title="Get live scores of New Zealand vs Afghanistan, 16th Match">Loss by 149 runs</a></td></tr><tr><td class="text-left">Pakistan</td><td class="text-left">22nd Match</td><td class="text-left">23 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75518/pak-vs-afg-22nd-match-icc-cricket-world-cup-2023" title="Get live scores of Pakistan vs Afghanistan, 22nd Match">Won by 8 wkts</a></td></tr><tr><td class="text-left">Sri Lanka</td><td class="text-left">30th Match</td><td class="text-left">30 Oct</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75549/sl-vs-afg-30th-match-icc-cricket-world-cup-2023" title="Get live scores of Sri Lanka vs Afghanistan, 30th Match">Won by 7 wkts</a></td></tr><tr><td class="text-left">Netherlands</td><td class="text-left">34th Match</td><td class="text-left">03 Nov</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75570/ned-vs-afg-34th-match-icc-cricket-world-cup-2023" title="Get live scores of Netherlands vs Afghanistan, 34th Match">Won by 7 wkts</a></td></tr><tr><td class="text-left">Australia</td><td class="text-left">39th Match</td><td class="text-left">07 Nov</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75609/aus-vs-afg-39th-match-icc-cricket-world-cup-2023" title="Get live scores of Australia vs Afghanistan, 39th Match">Loss by 3 wkts</a></td></tr><tr><td class="text-left">South Africa</td><td class="text-left">42nd Match</td><td class="text-left">10 Nov</td><td class="text-left"><a class="cb-text-link" href="/cricket-scores/75616/rsa-vs-afg-42nd-match-icc-cricket-world-cup-2023" title="Get live scores of South Africa vs Afghanistan, 42nd Match">Loss by 5 wkts</a></td></tr></table></div></td>, <td class="text-left">Bangladesh</td>, <td class="text-left">3rd Match</td>, <td class="text-left">07 Oct</td>, <td class="text-left"><a class="cb-text-link" href="/cricket-scores/75427/ban-vs-afg-3rd-match-icc-cricket-world-cup-2023" title="Get live scores of Bangladesh vs Afghanistan, 3rd Match">Loss by 6 wkts</a></td>, <td class="text-left">India</td>, <td class="text-left">9th Match</td>, <td class="text-left">11 Oct</td>, <td class="text-left"><a class="cb-text-link" href="/cricket-scores/75458/ind-vs-afg-9th-match-icc-cricket-world-cup-2023" title="Get live scores of India vs Afghanistan, 9th Match">Loss by 8 wkts</a></td>, <td class="text-left">England</td>, <td class="text-left">13th Match</td>, <td class="text-left">15 Oct</td>, <td class="tex ...
# [<th class="text-left">Opponent</th>, <th class="text-left">Description</th>, <th class="text-left">Date</th>, <th class="text-left">Result</th>]
# []
# [<th class="text-left">Opponent</th>, <th class="text-left">Description</th>, <th class="text-left">Date</th>, <th class="text-left">Result</th>]
# [<td class="text-left">Afghanistan</td>, <td class="text-left">3rd Match</td>, <td class="text-left">07 Oct</td>, <td class="text-left"><a class="cb-text-link" href="/cricket-scores/75427/afg-vs-ban-3rd-match-icc-cricket-world-cup-2023" title="Get live scores of Afghanistan vs Bangladesh, 3rd Match">Won by 6 wkts</a></td>]
# []
# [<td class="text-left">Pakistan</td>, <td class="text-left">8th Match</td>, <td class="text-left">10 Oct</td>, <td class="text-left"><a class="cb-text-link" href="/cricket-scores/75462/pak-vs-sl-8th-match-icc-cricket-world-cup-2023" title="Get live scores of Pakistan vs Sri Lanka, 8th Match">Loss by 6 wkts</a></td>]
# []
# [<td class="text-left">South Africa</td>, <td class="text-left">15th Match</td>, <td class="text-left">17 Oct</td>, <td class="text-left"><a class="cb-text-link" href="/cricket-scores/75486/rsa-vs-ned-15th-match-icc-cricket-world-cup-2023" title="Get live scores of South Africa vs Netherlands, 15th Match">Won by 38 runs (43 overs match)</a></td>]
# []

# %%
point = pd.read_excel(final_dataset_path+'Final_Point_table.xlsx')
point
# Out:
#            Team  Mat  Won  Lost  Tied  NR  Pts    NRR
# 0         India    9    9     0     0   0   18  2.570
# 1  South Africa    9    7     2     0   0   14  1.261
# 2     Australia    9    7     2     0   0   14  0.841
# 3   New Zealand    9    5     4     0   0   10  0.743
# 4      Pakistan    9    4     5     0   0    8 -0.199
# 5    Afganistan    9    4     5     0   0    8 -0.336
# 6       England    9    3     6     0   0    6 -0.572
# 7    Bangladesh    9    2     7     0   0    4 -1.087
# 8     Sri Lanka    9    2     7     0   0    4 -1.419
# 9   Netherlands    9    2     7     0   0    4 -1.825

# %%
point.to_csv(final_dataset_path+'FinalPointTable.csv',index=False)

# %% [markdown]
# ##7.  Play and Win Score on Ground

# %%
historical_matches = pd.read_csv(datasets_path+'historical_matches.csv')
historical_matches.head()
# Out:
#          Date       Team_1     Team_2       Winner     Margin  \
# 0  2015-01-08  Afghanistan   Scotland  Afghanistan  8 wickets
# 1  2015-01-11  New Zealand  Sri Lanka  New Zealand  3 wickets
# 2  2015-01-12      Ireland   Scotland      Ireland  3 wickets
# 3  2015-01-14  Afghanistan   Scotland     Scotland   150 runs
# 4  2015-01-15  New Zealand  Sri Lanka    Sri Lanka  6 wickets
#
#                                 Ground          City
# 0                          ICC Academy         Dubai
# 1                          Hagley Oval  Christchurch
# 2  Dubai International Cricket Stadium           NaN
# 3                 Sheikh Zayed Stadium     Abu Dhabi
# 4                          Seddon Park      Hamilton

# %%
historical_matches.shape
# Out:
# (1058, 7)

# %%
mask = historical_matches['City'].isin(worldcup_cities)

req_city_data = historical_matches[mask]

# Create a new DataFrame with the desired grouping
city_match_count = req_city_data.groupby('City').size().reset_index(name='Match_Count')
print(sum(city_match_count['Match_Count']))
# Display the new DataFrame
print(city_match_count)
# Out:
# 33
#          City  Match_Count
# 0   Ahmedabad            3
# 1   Bengaluru            2
# 2     Chennai            4
# 3       Delhi            3
# 4  Dharamsala            1
# 5   Hyderabad            2
# 6     Kolkata            3
# 7     Lucknow            4
# 8      Mumbai            5
# 9        Pune            6

# %%
req_city_data

req_data = req_city_data[['Team_1', 'Team_2', 'City', 'Winner']].reset_index(drop=True)
req_data

result23 = pd.read_csv(datasets_path+'result23.csv')
result23 = result23[['Team_1', 'Team_2', 'City', 'Winner']].reset_index(drop=True)[:45]
result23
final_ground_stats = pd.concat([req_data, result23])


final_ground_stats.head()
# Out:
#   Team_1        Team_2     City        Winner
# 0  India  South Africa  Chennai         India
# 1  India  South Africa   Mumbai  South Africa
# 2  India   New Zealand    Delhi   New Zealand
# 3  India       England     Pune         India
# 4  India       England  Kolkata       England

# %%
req_team1_data = final_ground_stats.groupby('Team_1').size().reset_index(name='Match_Count')
req_team2_data = final_ground_stats.groupby('Team_2').size().reset_index(name='Match_Count')

# %%
print(req_team1_data)
print(req_team2_data)
# Out:
#           Team_1  Match_Count
# 0    Afghanistan            4
# 1      Australia           10
# 2     Bangladesh            2
# 3        England            8
# 4          India           30
# 5    Netherlands            3
# 6    New Zealand            7
# 7       Pakistan            5
# 8   South Africa            6
# 9      Sri Lanka            1
# 10   West Indies            2
#           Team_2  Match_Count
# 0    Afghanistan            8
# 1      Australia            8
# 2     Bangladesh            7
# 3        England            6
# 4          India            9
# 5    Netherlands            6
# 6    New Zealand            6
# 7       Pakistan            4
# 8   South Africa            7
# 9      Sri Lanka           10
# 10   West Indies            7

# %%
cities = list(req_city_data['City'].unique())
teams = list(points_table['Team'].unique())

# %%
GroundPlayScore = []
for city in cities:
  instance = {}
  instance['Ground'] = city
  for team in teams:
    t1 = (final_ground_stats['Team_1'] == team) & (final_ground_stats['City'] == city)
    t2 = (final_ground_stats['Team_2'] == team) & (final_ground_stats['City'] == city)
    # w = (req_city_data['Winner'] == team) & (req_city_data['City'] == city)
    play_score = (t1 | t2).sum()
    instance[team] = play_score
  GroundPlayScore.append(instance)

# %%
pd.DataFrame(GroundPlayScore)
# Out:
#        Ground  South Africa  India  Australia  New Zealand  Pakistan  \
# 0     Chennai             2      5          3            2         2
# 1      Mumbai             3      6          3            1         0
# 2       Delhi             2      4          2            1         0
# 3        Pune             1      7          1            2         0
# 4     Kolkata             1      4          1            0         2
# 5   Bengaluru             0      3          3            2         2
# 6  Dharamsala             1      2          1            2         0
# 7   Hyderabad             0      2          1            2         2
# 8     Lucknow             2      2          2            0         0
# 9   Ahmedabad             1      4          1            1         1
#
#    Afghanistan  Sri Lanka  Netherlands  Bangladesh  England
# 0            2          0            0           1        0
# 1            1          1            0           1        1
# 2            2          2            1           1        1
# 3            1          1            1           2        5
# 4            0          1            1           2        2
# 5            0          2            1           0        1
# 6            1          1            1           2        1
# 7            0          1            2           0        0
# 8            4          2            2           0        1
# 9            1          0            0           0        2

# %%
GroundWinScore = []
for city in cities:
  instance = {}
  instance['Ground'] = city
  for team in teams:
    t1 = (final_ground_stats['Team_1'] == team) & (final_ground_stats['City'] == city)
    t2 = (final_ground_stats['Team_2'] == team) & (final_ground_stats['City'] == city)
    w = ((final_ground_stats['Winner'] == team) & (final_ground_stats['City'] == city)).sum()
    t = (t1 | t2).sum()
    if t > 0:
      win_score = w / t
    else:
      win_score = 0.33
    instance[team] = '%.2f' % (win_score)
  GroundWinScore.append(instance)

# %%
GroundWinScore = pd.DataFrame(GroundWinScore)
GroundWinScore.to_csv(datasets_path+'GroundWinScore.csv', index=False)

# %%
GroundWinScore
# Out:
#        Ground South Africa India Australia New Zealand Pakistan Afghanistan  \
# 0     Chennai         0.50  0.60      0.33        1.00     0.00        0.50
# 1      Mumbai         1.00  0.50      0.67        1.00     0.33        0.00
# 2       Delhi         0.50  0.50      1.00        1.00     0.33        0.50
# 3        Pune         1.00  0.71      1.00        0.00     0.33        1.00
# 4     Kolkata         0.00  0.75      0.00        0.33     0.50        0.33
# 5   Bengaluru         0.33  0.67      0.67        0.50     0.50        0.33
# 6  Dharamsala         0.00  0.50      1.00        0.00     0.33        0.00
# 7   Hyderabad         0.33  1.00      0.00        0.50     1.00        0.33
# 8     Lucknow         1.00  0.50      0.50        0.33     0.33        0.25
# 9   Ahmedabad         1.00  1.00      1.00        1.00     0.00        0.00
#
#   Sri Lanka Netherlands Bangladesh England
# 0      0.33        0.33       0.00    0.33
# 1      0.00        0.33       0.00    0.00
# 2      0.00        0.00       1.00    0.00
# 3      0.00        0.00       0.00    0.40
# 4      0.00        1.00       0.00    1.00
# 5      0.50        0.00       0.33    0.00
# 6      1.00        1.00       0.50    1.00
# 7      0.00        0.00       0.33    0.33
# 8      0.50        0.00       0.33    0.00
# 9      0.33        0.33       0.33    0.00
